# %% [markdown]
# ### Modelos del resto de productos

# %%
############################################
#Banano Jueves
############################################

t <- proc.time() 

RMSE2<-matrix(0, 1, 1)
MAPE2<-matrix(0, 1, 1)

trainbj<- data_Baj[1:243, 1:3]         
testbj<- data_Baj[244:305, 1:3] 
realbj<- data_Baj[293 : 307, 4]
bajy <- data_Baj[244:305, 1:3]

attach(testbj)
b<-Bajy 

for (j in 1:1) {


rango <-apply(trainbj[, j: 3], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainbj[, j: 3], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testbj)

b<-Bajy   
last_one<- nrow(testbj[, j: 3])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contbj1<-flag_1

compbj2<- testbj[last_one, length(testbj)]
while(compbj2 ==0){
  Bajy_r<-(predict(object.reg, within(testbj[,j:3], rm(Bajy))))
  
  if (contbj1<last_one) {
    testbj[contbj1+1,2]<- Bajy_r[contbj1]
    testbj[contbj1+1,1]<- Bajy_r[contbj1-1,]
      }
  
  contbj1<-contbj1+1
  testbj[contbj1,length(testbj)]<-Bajy_r[contbj1]
  compbj2<- testbj[last_one, length(testbj)]
}

b<-bajy 

Bajy_r[last_one]<-(predict(object.reg, within(testbj[last_one,j:3], rm(Bajy))))

# Error RMSE y MAPE
RMSEbj<- sqrt(sum((realbj-Bajy_r[47:61])^2)/(15))
MAPEbj<- sum(((abs(realbj- Bajy_r[47:61]))/realbj)*100)/(15)

RMSE2[1, j]<-RMSEbj
MAPE2[1, j]<-MAPEbj

trainbj<- data_Baj[1:243, 1:3]         
testbj<- data_Baj[244:305, 1:3] 
realbj<- data_Baj[293 : 307, 4]
bajy <- data_Baj[244:305, 1:3]


b<-Bajy 

}

proc.time()-t

############################################
#Banano Viernes
############################################

t <- proc.time()

trainbv<- data_Bav[1:243, 1:3]         
testbv<- data_Bav[244:305, 1:3]          
realbv<-data_Bav[293 : 307, 4]  
bavy <- data_Bav[244 : 305, 3]

RMSE3<-matrix(0, 1, 1)
MAPE3<-matrix(0, 1, 1)

attach(testbv)
b<-Bavy 


for (j in 1:1) {


rango <-apply(trainbv[, j: 3], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainbv[, j: 3], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testbv)

b<-Bavy   
last_one<- nrow(testbv[, j: 3])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contbv1<-flag_1

compbv2<- testbv[last_one, length(testbv)]
while(compbv2 ==0){
  Bavy_r<-(predict(object.reg, within(testbv[,j:3], rm(Bavy))))
  
  if (contbv1<last_one) {
    testbv[contbv1+1,2]<- Bavy_r[contbv1]
    testbv[contbv1+1,1]<- Bavy_r[contbv1-1,]
    
  }
  
  contbv1<-contbv1+1
  testbv[contbv1,length(testbv)]<-Bavy_r[contbv1]
  compbv2<- testbv[last_one, length(testbv)]
}

Bavy_r[last_one]<-(predict(object.reg, within(testbv[last_one,j:3], rm(Bavy))))

# Error RMSE y MAPE
RMSEbv<- sqrt(sum((realbv- Bavy_r[47:61])^2)/(15))
MAPEbv<- sum(((abs(realbv- Bavy_r[47:61]))/realbv)*100)/(15)

RMSE3[1, j]<-RMSEbv
MAPE3[1, j]<-MAPEbv

trainbv<- data_Bav[1:243, 1:3]         
testbv<- data_Bav[244:305, 1:3]          
realbv<-data_Bav[293 : 307, 4]  
bavy <- data_Bav[244 : 305, 3]

b<-Bavy 

}

proc.time()-t

############################################
#Mandarina martes
############################################

t <- proc.time() # Inicia el cronómetro

trainmm<- data_Mam[1:227, 1:9]         
testmm<- data_Mam[228:284, 1:9]          
realmm<-data_Mam[293 : 307, 10]  
mamy <- data_Mam[228 : 284, 9]

RMSE4<-matrix(0, 1, 7)
MAPE4<-matrix(0, 1, 7)

attach(testmm)
b<-Mamy 

for (j in 1:7) {

rango <-apply(trainmm[, j: 9], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainmm[, j: 9], rango, method.type="ANFIS", control)

#plotMF(object.reg)

summary(object.reg)

last_one<- nrow(testmm[, j: 9])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contmm1<-flag_1

compmm2<- testmm[last_one, length(testmm)]
while(compmm2 ==0){
  Mamy_r<-(predict(object.reg, within(testmm[, j: 9], rm(Mamy))))
  
  if (contmm1<last_one) {
    testmm[contmm1+1,8]<- Mamy_r[contmm1]
    testmm[contmm1+1,7]<- Mamy_r[contmm1-2,]
    testmm[contmm1+1,6]<- Mamy_r[contmm1-3,]
    testmm[contmm1+1,5]<- Mamy_r[contmm1-4,]
    testmm[contmm1+1,4]<- Mamy_r[contmm1-5,]
    testmm[contmm1+1,3]<- Mamy_r[contmm1-6,]
    testmm[contmm1+1,2]<- Mamy_r[contmm1-21,]
    testmm[contmm1+1,1]<- Mamy_r[contmm1-22,]
    }
  
  contmm1<-contmm1+1
  testmm[contmm1,length(testmm)]<-Mamy_r[contmm1]
  compmm2<- testmm[last_one, length(testmm)]
}

Mamy_r[last_one]<-(predict(object.reg, within(testmm[last_one,j:9], rm(Mamy))))

# Error RMSE y MAPE
RMSEmm<- sqrt(sum((realmm- Mamy_r[43:57])^2)/(15))
MAPEmm<- sum(((abs(realmm- Mamy_r[43:57]))/realmm)*100)/(15)


RMSE4[1, j]<-RMSEmm
MAPE4[1, j]<-MAPEmm

trainmm<- data_Mam[1:227, 1:9]         
testmm<- data_Mam[228:284, 1:9]          
realmm<-data_Mam[293 : 307, 10]  
mamy <- data_Mam[228 : 284, 9]

b<-mamy 
}

proc.time()-t

############################################
#Mandarina Jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainmj<- data_Maj[1:239, 1:7]         
testmj<- data_Maj[240:299, 1:7]          
realmj<-data_Maj[293 : 307, 8] 
majy <- data_Mam[240 : 299, 7]

RMSE5<-matrix(0, 1, 5)
MAPE5<-matrix(0, 1, 5)

attach(testmj)
b<-Majy 


for (j in 1:5) {
  
rango <-apply(trainmj[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainmj[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testmj)

b<-Majy   
last_one<- nrow(testmj[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contmj1<-flag_1

compmj2<- testmj[last_one, length(testmj)]
while(compmj2 ==0){
  Majy_r<-(predict(object.reg, within(testmj[, j: 7], rm(Majy))))
  
  if (contmj1<last_one) {
    testmj[contmj1+1,6]<- Majy_r[contmj1]
    testmj[contmj1+1,5]<- Majy_r[contmj1-2,]
    testmj[contmj1+1,4]<- Majy_r[contmj1-3,]
    testmj[contmj1+1,3]<- Majy_r[contmj1-4,]
    testmj[contmj1+1,2]<- Majy_r[contmj1-6,]
    testmj[contmj1+1,1]<- Majy_r[contmj1-7,]
  }
  
  contmj1<-contmj1+1
  testmj[contmj1,length(testmj)]<-Majy_r[contmj1]
  compmj2<- testmj[last_one, length(testmj)]
}

Majy_r[last_one]<-(predict(object.reg, within(testmj[last_one, j: 7], rm(Majy))))

# Error RMSE y MAPE
RMSEmj<- sqrt(sum((realmj- Majy_r[46:60])^2)/(15))
MAPEmj<- sum(((abs(realmj- Majy_r[46:60]))/realmj)*100)/(15)


RMSE5[1, j]<-RMSEmj
MAPE5[1, j]<-MAPEmj

trainmj<- data_Maj[1:239, 1:7]         
testmj<- data_Maj[240:299, 1:7]          
realmj<-data_Maj[293 : 307, 8] 
majy <- data_Maj[240 : 299, 7]

b<-majy 

}

proc.time()-t

############################################
#Mandarina viernes
############################################

t <- proc.time() # Inicia el cronómetro

trainmv<- data_Mav[1:230, 1:6]         
testmv<- data_Mav[231:287, 1:6]          
realmv<-data_Mav[293 : 307, 7] 
mavy <- data_Mav[231 : 287, 6]

RMSE6<-matrix(0, 1, 4)
MAPE6<-matrix(0, 1, 4)

attach(testmv)
b<-Mavy 

for (j in 1:4) {


rango <-apply(trainmv[, j: 6], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainmv[, j: 6], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testmv)

b<-Mavy   
last_one<- nrow(testmv[, j: 6])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contmv1<-flag_1

compmv2<- testmv[last_one, length(testmv)]
while(compmv2 ==0){
  Mavy_r<-(predict(object.reg, within(testmv[, j: 6], rm(Mavy))))
  
  if (contmv1<last_one) {
    testmv[contmv1+1,5]<- Mavy_r[contmv1]
    testmv[contmv1+1,4]<- Mavy_r[contmv1-3,]
    testmv[contmv1+1,3]<- Mavy_r[contmv1-4,]
    testmv[contmv1+1,2]<- Mavy_r[contmv1-5,]
    testmv[contmv1+1,1]<- Mavy_r[contmv1-19,]
    
  }
  
  contmv1<-contmv1+1
  testmv[contmv1,length(testmv)]<-Mavy_r[contmv1]
  compmv2<- testmv[last_one, length(testmv)]
}

Mavy_r[last_one]<-(predict(object.reg, within(testmv[last_one,j:6], rm(Mavy))))

# Error RMSE y MAPE
RMSEmv<- sqrt(sum((realmv- Mavy_r[43:57])^2)/(15))
MAPEmv<- sum(((abs(realmv- Mavy_r[43:57]))/realmv)*100)/(15)

RMSE6[1, j]<-RMSEmv
MAPE6[1, j]<-MAPEmv

trainmv<- data_Mav[1:230, 1:6]         
testmv<- data_Mav[231:287, 1:6]          
realmv<-data_Mav[293 : 307, 7] 
mavy <- data_Mav[231 : 287, 6]

b<-mavy 
}

proc.time()-t

############################################
#Naranja Martes
############################################

t <- proc.time() # Inicia el cronómetro

trainnm<- data_Nam[1:227, 1:6]         
testnm<- data_Nam[228:284, 1:6]          
realnm<-data_Nam[293 : 307, 7]  
namy <- data_Nam[228 : 284, 6]

RMSE7<-matrix(0, 1, 4)
MAPE7<-matrix(0, 1, 4)

attach(testnm)
b<-Namy 

for (j in 1:4) {
  
rango <-apply(trainnm[, j: 6], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainnm[, j: 6], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testnm)

b<-Namy   
last_one<- nrow(testnm[, j: 6])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contnm1<-flag_1

compnm2<- testnm[last_one, length(testnm)]
while(compnm2 ==0){
  Namy_r<-(predict(object.reg, within(testnm[, j: 6], rm(Namy))))
  
  if (contnm1<last_one) {
    testnm[contnm1+1,5]<- Namy_r[contnm1]
    testnm[contnm1+1,4]<- Namy_r[contnm1-1,]
    testnm[contnm1+1,3]<- Namy_r[contnm1-6,]
    testnm[contnm1+1,2]<- Namy_r[contnm1-8,]
    testnm[contnm1+1,1]<- Namy_r[contnm1-22,]
    }
  
  contnm1<-contnm1+1
  testnm[contnm1,length(testnm)]<-Namy_r[contnm1]
  compnm2<- testnm[last_one, length(testnm)]
}

Namy_r[last_one]<-(predict(object.reg, within(testnm[last_one,j: 6], rm(Namy))))

# Error RMSE y MAPE
RMSEnm<- sqrt(sum((realnm- Namy_r[43:57])^2)/(15))
MAPEnm<- sum(((abs(realnm- Namy_r[43:57]))/realnm)*100)/(15)

RMSE7[1, j]<-RMSEnm
MAPE7[1, j]<-MAPEnm

trainnm<- data_Nam[1:227, 1:6]         
testnm<- data_Nam[228:284, 1:6]          
realnm<-data_Nam[293 : 307, 7]  
namy <- data_Nam[228 : 284, 6]

b<-namy 
}

proc.time()-t

############################################
#Naranja Jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainnj<- data_Naj[1:227, 1:4]         
testnj<- data_Naj[228:284, 1:4]          
realnj<-data_Naj[293 : 307, 5] 
majy <- data_Naj[228 : 284, 4]

RMSE8<-matrix(0, 1, 2)
MAPE8<-matrix(0, 1, 2)

attach(testnj)
b<-Najy 

for (j in 1:2) {

rango <-apply(trainnj[, j: 4], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainnj[, j: 4], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testnj)

b<-Najy   
last_one<- nrow(testnj[, j: 4])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contnj1<-flag_1

compnj2<- testnj[last_one, length(testnj)]
while(compnj2 ==0){
  Najy_r<-(predict(object.reg, within(testnj[, j: 4], rm(Najy))))
  
  if (contnj1<last_one) {
    testnj[contnj1+1,3]<- Najy_r[contnj1]
    testnj[contnj1+1,2]<- Najy_r[contnj1-4,]
    testnj[contnj1+1,1]<- Najy_r[contnj1-22,]
    
   
      }
  
  contnj1<-contnj1+1
  testnj[contnj1, length(testnj)]<-Najy_r[contnj1]
  compnj2<- testnj[last_one, length(testnj)]
}

Najy_r[last_one]<-(predict(object.reg, within(testnj[last_one,j: 4], rm(Najy))))

# Error RMSE y MAPE
RMSEnj<- sqrt(sum((realnj- Najy_r[43:57])^2)/(15))
MAPEnj<- sum(((abs(realnj- Najy_r[43:57]))/realnj)*100)/(15)

RMSE8[1, j]<-RMSEnj
MAPE8[1, j]<-MAPEnj

trainnj<- data_Naj[1:227, 1:4]         
testnj<- data_Naj[228:284, 1:4]          
realnj<-data_Naj[293 : 307, 5] 
najy <- data_Naj[228 : 284, 4]


b<-najy 
}

proc.time()-t

############################################
#Naranja viernes
############################################

t <- proc.time() # Inicia el cronómetro

trainnv<- data_Nav[1:234, 1:7]         
testnv<- data_Nav[235:292, 1:7]          
realnv<-data_Nav[293 : 307, 8] 
navy <- data_Nav[235 : 292, 7]

RMSE9<-matrix(0, 1, 5)
MAPE9<-matrix(0, 1, 5)

attach(testnv)
b<-Navy

for (j in 1:5) {
  
rango <-apply(trainnv[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainnv[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testnv)

b<-Navy   
last_one<- nrow(testnv[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contnv1<-flag_1

compnv2<- testnv[last_one, length(testnv)]
while(compnv2 ==0){
  Navy_r<-(predict(object.reg, within(testnv[, j: 7], rm(Navy))))
  
  if (contnv1<last_one) {
    testnv[contnv1+1,6]<- Navy_r[contnv1]
    testnv[contnv1+1,5]<- Navy_r[contnv1-5,]
    testnv[contnv1+1,4]<- Navy_r[contnv1-6,]
    testnv[contnv1+1,3]<- Navy_r[contnv1-8,]
    testnv[contnv1+1,2]<- Navy_r[contnv1-12,]
    testnv[contnv1+1,1]<- Navy_r[contnv1-14,]
  }
  
  contnv1<-contnv1+1
  testnv[contnv1,length(testnv)]<-Navy_r[contnv1]
  compnv2<- testnv[last_one, length(testnv)]
}

Navy_r[last_one]<-(predict(object.reg, within(testnv[last_one,j: 7], rm(Navy))))

# Error RMSE y MAPE
RMSEnv<- sqrt(sum((realnv- Navy_r[44:58])^2)/(15))
MAPEnv<- sum(((abs(realnv- Navy_r[44:58]))/realnv)*100)/(15)

RMSE9[1, j]<-RMSEnv
MAPE9[1, j]<-MAPEnv

trainnv<- data_Nav[1:234, 1:7]         
testnv<- data_Nav[235:292, 1:7]          
realnv<-data_Nav[293 : 307, 8] 
navy <- data_Nav[235 : 292, 7]

b<-navy
}

proc.time()-t

############################################
#Papa martes
############################################

t <- proc.time() # Inicia el cronómetro

trainppm<- data_Pam[1:234, 1:7]         
testppm<- data_Pam[235:293, 1:7]          
realppm<-data_Pam[293 : 307, 8]
pamy <- data_Pam[235 : 293, 7]

RMSE10<-matrix(0, 1, 5)
MAPE10<-matrix(0, 1, 5)

attach(testppm)
b<-Pamy 

for (j in 1:5) {
  
rango <-apply(trainppm[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainppm[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testppm)

b<-Pamy   
last_one<- nrow(testppm[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contppm1<-flag_1

compppm2<- testppm[last_one, length(testppm)]
while(compppm2 ==0){
  Pamy_r<-(predict(object.reg, within(testppm[, j: 7], rm(Pamy))))
  
  if (contppm1<last_one) {
    testppm[contppm1+1,6]<- Pamy_r[contppm1]
    testppm[contppm1+1,5]<- Pamy_r[contppm1-1,]
    testppm[contppm1+1,4]<- Pamy_r[contppm1-6,]
    testppm[contppm1+1,3]<- Pamy_r[contppm1-7,]
    testppm[contppm1+1,2]<- Pamy_r[contppm1-9,]
    testppm[contppm1+1,1]<- Pamy_r[contppm1-13,]
    
    }
  
  contppm1<-contppm1+1
  testppm[contppm1,length(testppm)]<-Pamy_r[contppm1]
  compppm2<- testppm[last_one, length(testppm)]
}

Pamy_r[last_one]<-(predict(object.reg, within(testppm[last_one,j: 7], rm(Pamy))))

# Error RMSE y MAPE

RMSEppm<- sqrt(sum((realppm- Pamy_r[45:59])^2)/(15))
MAPEppm<- sum(((abs(realppm- Pamy_r[45:59]))/realppm)*100)/(15)

RMSE10[1, j]<-RMSEppm
MAPE10[1, j]<-MAPEppm

trainppm<- data_Pam[1:234, 1:7]         
testppm<- data_Pam[235:293, 1:7]          
realppm<-data_Pam[293 : 307, 8]
pamy <- data_Pam[235 : 293, 7]

b<-pamy 

}

proc.time()-t

############################################
#Papa jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainppj<- data_Paj[1:234, 1:7]         
testppj<- data_Paj[235:293, 1:7]          
realppj<-data_Paj[293 : 307, 8]
pajy <- data_Paj[235 : 293, 7]


RMSE11<-matrix(0, 1, 5)
MAPE11<-matrix(0, 1, 5)

attach(testppj)
b<-Pajy 

for (j in 1:5) {
  

rango <-apply(trainppj[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainppj[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testppj)

b<-Pajy   
last_one<- nrow(testppj[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contppj1<-flag_1

compppj2<- testppj[last_one, length(testppj)]
while(compppj2 ==0){
  Pajy_r<-(predict(object.reg, within(testppj[, j: 7], rm(Pajy))))
  
  if (contppj1<last_one) {
    testppj[contppj1+1,6]<- Pajy_r[contppj1]
    testppj[contppj1+1,5]<- Pajy_r[contppj1-4,]
    testppj[contppj1+1,4]<- Pajy_r[contppj1-6,]
    testppj[contppj1+1,3]<- Pajy_r[contppj1-9,]
    testppj[contppj1+1,2]<- Pajy_r[contppj1-13,]
    testppj[contppj1+1,1]<- Pajy_r[contppj1-14,]
  }
  
  contppj1<-contppj1+1
  testppj[contppj1,length(testppj)]<-Pajy_r[contppj1]
  compppj2<- testppj[last_one, length(testppj)]
}

Pajy_r[last_one]<-(predict(object.reg, within(testppj[last_one,j: 7], rm(Pajy))))

# Error RMSE y MAPE

RMSEppj<- sqrt(sum((realppj- Pajy_r[44:58])^2)/(15))
MAPEppj<- sum(((abs(realppj- Pajy_r[44:58]))/realppj)*100)/(15)


RMSE11[1, j]<-RMSEppj
MAPE11[1, j]<-MAPEppj

trainppj<- data_Paj[1:234, 1:7]         
testppj<- data_Paj[235:293, 1:7]          
realppj<-data_Paj[293 : 307, 8]
pajy <- data_Paj[235 : 293, 7]

b<-pajy

}

proc.time()-t

############################################
#Papa viernes
############################################

t <- proc.time() # Inicia el cronómetro

trainppv<- data_Pav[1:238, 1:4]         
testppv<- data_Pav[239:297, 1:4]          
realppv<-data_Pav[293 : 307, 5]
pavy <- data_Pav[239:297, 4]

RMSE12<-matrix(0, 1, 2)
MAPE12<-matrix(0, 1, 2)

attach(testmm)
b<-Mamy 

for (j in 1:2) {
  
rango <-apply(trainppv[, j: 4], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainppv[, j: 4], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testppv)

b<-Pavy   
last_one<- nrow(testppv[, j: 4])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contppv1<-flag_1

compppv2<- testppv[last_one, length(testppv)]
while(compppv2 ==0){
  Pavy_r<-(predict(object.reg, within(testppv[, j: 4], rm(Pavy))))
  
  if (contppv1<last_one) {
    testppv[contppv1+1,3]<- Pavy_r[contppv1]
    testppv[contppv1+1,2]<- Pavy_r[contppv1-4,]
    testppv[contppv1+1,1]<- Pavy_r[contppv1-9,]
    
  }
  
  contppv1<-contppv1+1
  testppv[contppv1,length(testppv)]<-Pavy_r[contppv1]
  compppv2<- testppv[last_one, length(testppv)]
}

Pavy_r[last_one]<-(predict(object.reg, within(testppv[last_one,j: 4], rm(Pavy))))

# Error RMSE y MAPE
RMSEppv<- sqrt(sum((realppv- Pavy_r[45:59])^2)/(15))
MAPEppv<- sum(((abs(realppv- Pavy_r[45:59]))/realppv)*100)/(15)

RMSE12[1, j]<-RMSEppv
MAPE12[1, j]<-MAPEppv

trainppv<- data_Pav[1:238, 1:4]         
testppv<- data_Pav[239:297, 1:4]          
realppv<-data_Pav[293 : 307, 5]
pavy <- data_Pav[239:297, 4]

b<-pavy 
}

proc.time()-t

############################################
#Piña martes
############################################

t <- proc.time() # Inicia el cronómetro

trainpim<- data_Pim[1:226, 1:6]         
testpim<- data_Pim[227:283, 1:6]          
realpim<-data_Pim[293 : 307, 7] 
pimy <- data_Pim[227:283, 6]

RMSE13<-matrix(0, 1, 4)
MAPE13<-matrix(0, 1, 4)

attach(testpim)
b<-Pimy 

for (j in 1:4) {

rango <-apply(trainpim[, j: 6], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainpim[, j: 6], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testpim)

b<-Pimy   
last_one<- nrow(testpim[, j: 6])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contpim1<-flag_1

comppim2<- testpim[last_one, length(testpim)]
while(comppim2 ==0){
  Pimy_r<-(predict(object.reg, within(testpim[, j: 6], rm(Pimy))))
  
  if (contpim1<last_one) {
    testpim[contpim1+1,5]<- Pimy_r[contpim1]
    testpim[contpim1+1,4]<- Pimy_r[contpim1-1,]
    testpim[contpim1+1,3]<- Pimy_r[contpim1-9,]
    testpim[contpim1+1,2]<- Pimy_r[contpim1-20,]
    testpim[contpim1+1,1]<- Pimy_r[contpim1-23,]
  }
  
  contpim1<-contpim1+1
  testpim[contpim1,length(testpim)]<-Pimy_r[contpim1]
  comppim2<- testpim[last_one, length(testpim)]
}

Pimy_r[last_one]<-(predict(object.reg, within(testpim[last_one,j: 6], rm(Pimy))))

# Error RMSE y MAPE
RMSEpim<- sqrt(sum((realpim- Pimy_r[43:57])^2)/(15))
MAPEpim<- sum(((abs(realpim- Pimy_r[43:57]))/realpim)*100)/(15)

RMSE13[1, j]<-RMSEpim
MAPE13[1, j]<-MAPEpim

trainpim<- data_Pim[1:226, 1:6]         
testpim<- data_Pim[227:283, 1:6]          
realpim<-data_Pim[293 : 307, 7] 
pimy <- data_Pim[227:283, 6]

b<-pimy 

}

proc.time()-t

############################################
#Piña jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainpij<- data_Pij[1:234, 1:4]         
testpij<- data_Pij[235:293, 1:4]          
realpij<-data_Pij[293 : 307, 5]
pijy <- data_Pij[235:293, 4]

RMSE14<-matrix(0, 1, 2)
MAPE14<-matrix(0, 1, 2)

attach(testpij)
b<-Pijy 

for (j in 1:2) {
  
rango <-apply(trainpij[, j: 4], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainpij[, j: 4], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testpij)

b<-Pijy   
last_one<- nrow(testpij[, j: 4])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contpij1<-flag_1

comppij2<- testpij[last_one, length(testpij)]
while(comppij2 ==0){
  Pijy_r<-(predict(object.reg, within(testpij[, j: 4], rm(Pijy))))
  
  if (contpij1<last_one) {
    testpij[contpij1+1,3]<- Pijy_r[contpij1]
    testpij[contpij1+1,2]<- Pijy_r[contpij1-1,]
    testpij[contpij1+1,1]<- Pijy_r[contpij1-13,]
    
  }
  
  contpij1<-contpij1+1
  testpij[contpij1,length(testpij)]<-Pijy_r[contpij1]
  comppij2<- testpij[last_one, length(testpij)]
}

Pijy_r[last_one]<-(predict(object.reg, within(testpij[last_one,j: 4], rm(Pijy))))

# Error RMSE y MAPE
RMSEpij<- sqrt(sum((realpij- Pijy_r[45:59])^2)/(15))
MAPEpij<- sum(((abs(realpij- Pijy_r[45:59]))/realpij)*100)/(15)

RMSE14[1, j]<-RMSEpij
MAPE14[1, j]<-MAPEpij

trainpij<- data_Pij[1:234, 1:4]         
testpij<- data_Pij[235:293, 1:4]          
realpij<-data_Pij[293 : 307, 5]
pijy <- data_Pij[235:293, 4]

b<-pijy 
}

proc.time()-t

############################################
#Piña viernes
############################################

t <- proc.time() # Inicia el cronómetro

trainpiv<- data_Piv[1:233, 1:5]         
testpiv<- data_Piv[234:291, 1:5]          
realpiv<-data_Piv[293 : 307, 6] 
pivy <- data_Piv[234 : 291, 5]

RMSE15<-matrix(0, 1, 3)
MAPE15<-matrix(0, 1, 3)

attach(testpiv)
b<-Pivy 

for (j in 1:3) {
  
rango <-apply(trainpiv[, j: 5], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainpiv[, j: 5], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testpiv)

b<-Pivy   
last_one<- nrow(testpiv)

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contpiv1<-flag_1

comppiv2<- testpiv[last_one, length(testpiv)]
while(comppiv2 ==0){
  Pivy_r<-(predict(object.reg, within(testpiv[, j: 5], rm(Pivy))))
  
  if (contpiv1<last_one) {
    testpiv[contpiv1+1,4]<- Pivy_r[contpiv1]
    testpiv[contpiv1+1,3]<- Pivy_r[contpiv1-1,]
    testpiv[contpiv1+1,2]<- Pivy_r[contpiv1-13,]
    testpiv[contpiv1+1,1]<- Pivy_r[contpiv1-15,]
    
  }
  
  contpiv1<-contpiv1+1
  testpiv[contpiv1,length(testpiv)]<-Pivy_r[contpiv1]
  comppiv2<- testpiv[last_one, length(testpiv)]
}

Pivy_r[last_one]<-(predict(object.reg, within(testpiv[last_one,j: 5], rm(Pivy))))

# Error RMSE y MAPE
RMSEpiv<- sqrt(sum((realpiv- Pivy_r[44:58])^2)/(15))
MAPEpiv<- sum(((abs(realpiv- Pivy_r[44:58]))/realpiv)*100)/(15)

RMSE15[1, j]<-RMSEpiv
MAPE15[1, j]<-MAPEpiv

trainpiv<- data_Piv[1:233, 1:5]         
testpiv<- data_Piv[234:291, 1:5]          
realpiv<-data_Piv[293 : 307, 6] 
pivy <- data_Piv[234 : 291, 5]

b<-pivy 

}

proc.time()-t

############################################
#Platano martes
############################################

t <- proc.time() # Inicia el cronómetro

trainplm<- data_Plm[1:244, 1:3]         
testplm<- data_Plm[245:305, 1:3]          
realplm<-data_Plm[293 : 307, 4]
plmy <- data_Plm[245 : 305, 3]

RMSE16<-matrix(0, 1, 1)
MAPE16<-matrix(0, 1, 1)

attach(testplm)
b<-Plmy 

for (j in 1:1) {
  
rango <-apply(trainplm[, j: 3], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainplm[, j: 3], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testplm)

b<-Plmy   
last_one<- nrow(testplm[, j: 3])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contplm1<-flag_1

compplm2<- testplm[last_one, length(testplm)]
while(compplm2 ==0){
  Plmy_r<-(predict(object.reg, within(testplm[, j: 3], rm(Plmy))))
  
  if (contplm1<last_one) {
    testplm[contplm1+1,2]<- Plmy_r[contplm1]
    testplm[contplm1+1,1]<- Plmy_r[contplm1-1,]
    
  }
  
  contplm1<-contplm1+1
  testplm[contplm1,length(testplm)]<-Plmy_r[contplm1]
  compplm2<- testplm[last_one, length(testplm)]
}

Plmy_r[last_one]<-(predict(object.reg, within(testplm[last_one,j: 3], rm(Plmy))))

# Error RMSE y MAPE
RMSEplm<- sqrt(sum((realplm- Plmy_r[47:61])^2)/(15))
MAPEplm<- sum(((abs(realplm- Plmy_r[47:61]))/realplm)*100)/(15)

RMSE16[1, j]<-RMSEplm
MAPE16[1, j]<-MAPEplm

trainplm<- data_Plm[1:244, 1:3]         
testplm<- data_Plm[245:305, 1:3]          
realplm<-data_Plm[293 : 307, 4]
plmy <- data_Plm[245 : 305, 3]

b<-plmy 
}

proc.time()-t

############################################
#Platano jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainplj<- data_Plj[1:244, 1:3]         
testplj<- data_Plj[245:305, 1:3]          
realplj<-data_Plj[293 : 307, 4]
pljy <- data_Plj[245:305, 3]

RMSE17<-matrix(0, 1, 1)
MAPE17<-matrix(0, 1, 1)

attach(testplj)
b<-Pljy 

for (j in 1:1) {

rango <-apply(trainplj[, j: 3], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainplj[, j: 3], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testplj)

b<-Pljy   
last_one<- nrow(testplj[, j: 3])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contplj1<-flag_1

compplj2<- testplj[last_one, length(testplj)]
while(compplj2 ==0){
  Pljy_r<-(predict(object.reg, within(testplj[, j: 3], rm(Pljy))))
  
  if (contplj1<last_one) {
    testplj[contplj1+1,2]<- Pljy_r[contplj1]
    testplj[contplj1+1,1]<- Pljy_r[contplj1-1,]
    
  }
  
  contplj1<-contplj1+1
  testplj[contplj1,length(testplj)]<-Pljy_r[contplj1]
  compplj2<- testplj[last_one, length(testplj)]
}

Pljy_r[last_one]<-(predict(object.reg, within(testplj[last_one,j: 3], rm(Pljy))))

# Error RMSE y MAPE
RMSEplj<- sqrt(sum((realplj- Pljy_r[47:61])^2)/(15))
MAPEplj<- sum(((abs(realplj- Pljy_r[47:61]))/realplj)*100)/(15)

RMSE17[1, j]<-RMSEplj
MAPE17[1, j]<-MAPEplj

trainplj<- data_Plj[1:244, 1:3]         
testplj<- data_Plj[245:305, 1:3]          
realplj<-data_Plj[293 : 307, 4]
pljy <- data_Plj[245:305, 3]

b<-Pljy 

}

proc.time()-t

############################################
#Platano viernes
############################################

t <- proc.time() # Inicia el cronómetro

trainplv<- data_Plv[1:229, 1:4]         
testplv<- data_Plv[230:286, 1:4]          
realplv<-data_Plv[293 : 307, 5] 
plvy <- data_Plv[228 : 284, 9]

RMSE18<-matrix(0, 1, 2)
MAPE18<-matrix(0, 1, 2)

attach(testplv)
b<-Plvy 

for (j in 1:2) {
  
rango <-apply(trainplv[, j: 4], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainplv[, j: 4], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testplv)

b<-Plvy   
last_one<- nrow(testplv[, j: 4])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contplv1<-flag_1

compplv2<- testplv[last_one, length(testplv)]
while(compplv2 ==0){
  Plvy_r<-(predict(object.reg, within(testplv[, j: 4], rm(Plvy))))
  
  if (contplv1<last_one) {
    testplv[contplv1+1,3]<- Plvy_r[contplv1]
    testplv[contplv1+1,2]<- Plvy_r[contplv1-1,]
    testplv[contplv1+1,1]<- Plvy_r[contplv1-20,]
  }
  
  contplv1<-contplv1+1
  testplv[contplv1,length(testplv)]<-Plvy_r[contplv1]
  compplv2<- testplv[last_one, length(testplv)]
}

Plvy_r[last_one]<-(predict(object.reg, within(testplv[last_one,j: 4], rm(Plvy))))

# Error RMSE y MAPE
RMSEplv<- sqrt(sum((realplv- Plvy_r[43:57])^2)/(15))
MAPEplv<- sum(((abs(realplv- Plvy_r[43:57]))/realplv)*100)/(15)

RMSE18[1, j]<-RMSEplv
MAPE18[1, j]<-MAPEplv

trainplv<- data_Plv[1:229, 1:4]         
testplv<- data_Plv[230:286, 1:4]          
realplv<-data_Plv[293 : 307, 5] 
plvy <- data_Plv[228 : 284, 9]

b<-Plvy 
}

proc.time()-t

######################################
#Tomate martes
############################################

t <- proc.time() # Inicia el cronómetro

traintom<- data_Tom[1:233, 1:4]         
testtom<- data_Tom[234:291, 1:4]          
realtom<-data_Tom[293 : 307, 5]
tomy <- data_Tom[234 : 291, 4]

RMSE19<-matrix(0, 1, 2)
MAPE19<-matrix(0, 1, 2)

attach(testtom)
b<-Tomy 

for (j in 1:2) {
  
rango <-apply(traintom[, j: 4], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(traintom[, j: 4], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testtom)

b<-Tomy   
last_one<- nrow(testtom[, j: 4])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

conttom1<-flag_1

comptom2<- testtom[last_one, length(testtom)]
while(comptom2 ==0){
  Tomy_r<-(predict(object.reg, within(testtom[, j: 4], rm(Tomy))))
  
  if (conttom1<last_one) {
    testtom[conttom1+1,3]<- Tomy_r[conttom1]
    testtom[conttom1+1,2]<- Tomy_r[conttom1-9,]
    testtom[conttom1+1,1]<- Tomy_r[conttom1-15,]
    
    }
  
  conttom1<-conttom1+1
  testtom[conttom1,length(testtom)]<-Tomy_r[conttom1]
  comptom2<- testtom[last_one, length(testtom)]
}

Tomy_r[last_one]<-(predict(object.reg, within(testtom[last_one,j: 4], rm(Tomy))))

# Error RMSE y MAPE
RMSEtom<- sqrt(sum((realtom- Tomy_r[44:58])^2)/(15))
MAPEtom<- sum(((abs(realtom- Tomy_r[44:58]))/realtom)*100)/(15)

RMSE19[1, j]<-RMSEtom
MAPE19[1, j]<-MAPEtom

traintom<- data_Tom[1:233, 1:4]         
testtom<- data_Tom[234:291, 1:4]          
realtom<-data_Tom[293 : 307, 5]
tomy <- data_Tom[234 : 291, 4]

b<-tomy 

}

proc.time()-t

############################################
#Tomate jueves
############################################

t <- proc.time() # Inicia el cronómetro

traintoj<- data_Toj[1:226, 1:6]         
testtoj<- data_Toj[227:283, 1:6]          
realtoj<-data_Toj[293 : 307, 7]  
tojy <- data_Toj[227:283, 6]

RMSE20<-matrix(0, 1, 4)
MAPE20<-matrix(0, 1, 4)

attach(testtoj)
b<-Tojy

for (j in 1:4) {

rango <-apply(traintoj[, j: 6], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(traintoj[, j: 6], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testtoj)

b<-Tojy   
last_one<- nrow(testtoj[, j: 6])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

conttoj1<-flag_1

comptoj2<- testtoj[last_one, length(testtoj)]
while(comptoj2 ==0){
  Tojy_r<-(predict(object.reg, within(testtoj[, j: 6], rm(Tojy))))
  
  if (conttoj1<last_one) {
    testtoj[conttoj1+1,5]<- Tojy_r[conttoj1]
    testtoj[conttoj1+1,4]<- Tojy_r[conttoj1-2,]
    testtoj[conttoj1+1,3]<- Tojy_r[conttoj1-10,]
    testtoj[conttoj1+1,2]<- Tojy_r[conttoj1-15,]
    testtoj[conttoj1+1,1]<- Tojy_r[conttoj1-23,]
  }
  
  conttoj1<-conttoj1+1
  testtoj[conttoj1,length(testtoj)]<-Tojy_r[conttoj1]
  comptoj2<- testtoj[last_one, length(testtoj)]
}

Tojy_r[last_one]<-(predict(object.reg, within(testtoj[last_one,j: 6], rm(Tojy))))

# Error RMSE y MAPE
RMSEtoj<- sqrt(sum((realtoj- Tojy_r[43:57])^2)/(15))
MAPEtoj<- sum(((abs(realtoj- Tojy_r[43:57]))/realtoj)*100)/(15)

RMSE20[1, j]<-RMSEtoj
MAPE20[1, j]<-MAPEtoj

traintoj<- data_Toj[1:226, 1:6]         
testtoj<- data_Toj[227:283, 1:6]          
realtoj<-data_Toj[293 : 307, 7]  
tojy <- data_Toj[227:283, 6]

b<-Tojy

}

proc.time()-t

############################################
#Tomate viernes
############################################

t <- proc.time() # Inicia el cronómetro

traintov<- data_Tov[1:233, 1:7]         
testtov<- data_Tov[234:291, 1:7]          
realtov<-data_Tov[293 : 307, 8]  
tovy <- data_Tov[234:291, 7]

RMSE21<-matrix(0, 1, 5)
MAPE21<-matrix(0, 1, 5)

attach(testtov)
b<-Tovy 

for (j in 1:5) {

rango <-apply(traintov[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(traintov[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testtov)

b<-Tovy   
last_one<- nrow(testtov[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

conttov1<-flag_1

comptov2<- testtov[last_one, length(testtov)]
while(comptov2 ==0){
  Tovy_r<-(predict(object.reg, within(testtov[, j: 7], rm(Tovy))))
  
  if (conttov1<last_one) {
    testtov[conttov1+1,6]<- Tovy_r[conttov1]
    testtov[conttov1+1,5]<- Tovy_r[conttov1-1,]
    testtov[conttov1+1,4]<- Tovy_r[conttov1-2,]
    testtov[conttov1+1,3]<- Tovy_r[conttov1-7,]
    testtov[conttov1+1,2]<- Tovy_r[conttov1-9,]
    testtov[conttov1+1,1]<- Tovy_r[conttov1-15,]
         }
  
  conttov1<-conttov1+1
  testtov[conttov1,length(testtov)]<-Tovy_r[conttov1]
  comptov2<- testtov[last_one, length(testtov)]
}

Tovy_r[last_one]<-(predict(object.reg, within(testtov[last_one,j: 7], rm(Tovy))))

# Error RMSE y MAPE
RMSEtov<- sqrt(sum((realtov- Tovy_r[44:58])^2)/(15))
MAPEtov<- sum(((abs(realtov- Tovy_r[44:58]))/realtov)*100)/(15)

RMSE21[1, j]<-RMSEtov
MAPE21[1, j]<-MAPEtov

traintov<- data_Tov[1:233, 1:7]         
testtov<- data_Tov[234:291, 1:7]          
realtov<-data_Tov[293 : 307, 8]  
tovy <- data_Tov[234:291, 7]

b<-tovy 
}

proc.time()-t

############################################
#Yuca martes
############################################

t <- proc.time() # Inicia el cronómetro

trainyum<- data_Yum[1:234, 1:5]         
testyum<- data_Yum[235:293, 1:5]          
realyum<-data_Yum[293 : 307, 6] 
yumy <- data_Yum[235:293, 5]

RMSE22<-matrix(0, 1, 3)
MAPE22<-matrix(0, 1, 3)

attach(testyum)
b<-Yumy 

for (j in 1:3) {
  
rango <-apply(trainyum[, j: 5], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainyum[, j: 5], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testyum)

b<-Yumy   
last_one<- nrow(testyum[, j: 5])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contyum1<-flag_1

compyum2<- testyum[last_one, length(testyum)]
while(compyum2 ==0){
  Yumy_r<-(predict(object.reg, within(testyum[, j: 5], rm(Yumy))))
  
  if (contyum1<last_one) {
    testyum[contyum1+1,2]<- Yumy_r[contyum1]
    testyum[contyum1+1,1]<- Yumy_r[contyum1-1,]
    testyum[contyum1+1,1]<- Yumy_r[contyum1-2,]
    testyum[contyum1+1,1]<- Yumy_r[contyum1-3,]
    testyum[contyum1+1,1]<- Yumy_r[contyum1-13,]
    }
  
  contyum1<-contyum1+1
  testyum[contyum1,length(testyum)]<-Yumy_r[contyum1]
  compyum2<- testyum[last_one, length(testyum)]
}

Yumy_r[last_one]<-(predict(object.reg, within(testyum[last_one,j: 5], rm(Yumy))))

# Error RMSE y MAPE
RMSEyum<- sqrt(sum((realyum- Yumy_r[45:59])^2)/(15))
MAPEyum<- sum(((abs(realyum- Yumy_r[45:59]))/realyum)*100)/(15)

RMSE22[1, j]<-RMSEyum
MAPE22[1, j]<-MAPEyum

trainyum<- data_Yum[1:234, 1:5]         
testyum<- data_Yum[235:293, 1:5]          
realyum<-data_Yum[293 : 307, 6] 
yumy <- data_Yum[235:293, 5]

b<-yumy 
}

proc.time()-t

############################################
#Yuca jueves
############################################

t <- proc.time() # Inicia el cronómetro

trainyuj<- data_Yuj[1:236, 1:6]         
testyuj<- data_Yuj[237:295, 1:6]          
realyuj<-data_Yuj[293 : 307, 7] 
yujy <- data_Yuj[237 : 295, 6]

RMSE23<-matrix(0, 1, 4)
MAPE23<-matrix(0, 1, 4)

attach(testyuj)
b<-Yujy 

for (j in 1:4) {
  
rango <-apply(trainyuj[, j: 6], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainyuj[, j: 6], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testyuj)

b<-Yujy   
last_one<- nrow(testyuj[, j: 6])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contyuj1<-flag_1

compyuj2<- testyuj[last_one, length(testyuj)]
while(compyuj2 ==0){
  Yujy_r<-(predict(object.reg, within(testyuj[, j: 6], rm(Yujy))))
  
  if (contyuj1<last_one) {
    testyuj[contyuj1+1,5]<- Yujy_r[contyuj1]
    testyuj[contyuj1+1,4]<- Yujy_r[contyuj1-1,]
    testyuj[contyuj1+1,3]<- Yujy_r[contyuj1-2,]
    testyuj[contyuj1+1,2]<- Yujy_r[contyuj1-3,]
    testyuj[contyuj1+1,1]<- Yujy_r[contyuj1-11,]
    }
  
  contyuj1<-contyuj1+1
  testyuj[contyuj1,length(testyuj)]<-Yujy_r[contyuj1]
  compyuj2<- testyuj[last_one, length(testyuj)]
}

Yujy_r[last_one]<-(predict(object.reg, within(testyuj[last_one,j: 6], rm(Yujy))))

# Error RMSE y MAPE
RMSEyuj<- sqrt(sum((realyuj- Yujy_r[45:59])^2)/(15))
MAPEyuj<- sum(((abs(realyuj- Yujy_r[45:59]))/realyuj)*100)/(15)

RMSE23[1, j]<-RMSEyuj
MAPE23[1, j]<-MAPEyuj

trainyuj<- data_Yuj[1:236, 1:6]         
testyuj<- data_Yuj[237:295, 1:6]          
realyuj<-data_Yuj[293 : 307, 7] 
yujy <- data_Yuj[237 : 295, 6]

b<-yujy 
}

proc.time()-t

############################################
#Yuca viernes
############################################

t <- proc.time()

trainyuv<- data_Yuv[1:238, 1:7]         
testyuv<- data_Yuv[239:297, 1:7]          
realyuv<-data_Yuv[293 : 307, 8]
yuvy <- data_Yuv[239: 297, 7]

RMSE24<-matrix(0, 1, 5)
MAPE24<-matrix(0, 1, 5)

attach(testyuv)
b<-Yuvy 

for (j in 1:5) {

rango <-apply(trainyuv[, j: 7], 2, range)

control <- list(num.labels = 3, type.mf= "GAUSSIAN",  step.size = 0.01, type.tnorm = "MIN", type.snorm = "MAX",
                type.implication.func = "ZADEH")

object.reg <- frbs.learn(trainyuv[, j: 7], rango, method.type="ANFIS", control)

plotMF(object.reg)

summary(object.reg)

attach(testyuv)

b<-Yuvy   
last_one<- nrow(testyuv[, j: 7])

##########################################
flag_1<-0
stop_1<-0
paso_1<-1

while (stop_1==0) {
  if(b[paso_1]!=0)
  {
    flag_1=flag_1+1
  } else{
    stop_1=1
  }
  paso_1=paso_1+1
}
##########################################

contyuv1<-flag_1

compyuv2<- testyuv[last_one, length(testyuv)]
while(compyuv2 ==0){
  Yuvy_r<-(predict(object.reg, within(testyuv[, j: 7], rm(Yuvy))))
  
  if (contyuv1<last_one) {
    testyuv[contyuv1+1,6]<- Yuvy_r[contyuv1]
    testyuv[contyuv1+1,5]<- Yuvy_r[contyuv1-1,]
    testyuv[contyuv1+1,4]<- Yuvy_r[contyuv1-2,]
    testyuv[contyuv1+1,3]<- Yuvy_r[contyuv1-3,]
    testyuv[contyuv1+1,2]<- Yuvy_r[contyuv1-6,]
    testyuv[contyuv1+1,1]<- Yuvy_r[contyuv1-9,] 
     }
  
  contyuv1<-contyuv1+1
  testyuv[contyuv1,length(testyuv)]<-Yuvy_r[contyuv1]
  compyuv2<- testyuv[last_one, length(testyuv)]
}

Yuvy_r[last_one]<-(predict(object.reg, within(testyuv[last_one,j: 7], rm(Yuvy))))

# Error RMSE y MAPE
RMSEyuv<- sqrt(sum((realyuv- Yuvy_r[45:59])^2)/(15))
MAPEyuv<- sum(((abs(realyuv- Yuvy_r[45:59]))/realyuv)*100)/(15)

RMSE24[1, j]<-RMSEyuv
MAPE24[1, j]<-MAPEyuv

trainyuv<- data_Yuv[1:238, 1:7]         
testyuv<- data_Yuv[239:297, 1:7]          
realyuv<-data_Yuv[293 : 307, 8]
yuvy <- data_Yuv[239: 297, 7]

b<-yuvy 

}

proc.time()-t
